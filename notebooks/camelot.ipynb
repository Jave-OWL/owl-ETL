# %%
import camelot

# %%
# stream: space separated tables
stream_tables = camelot.read_pdf('unoDeCadaUno/bancolombia_fiducuenta.pdf', pages='all', flavor='stream')

for table in stream_tables:
    print('Stream Table')
    print(table.df) # df means we convert the table to a pandas df
# Out:
# Stream Table
#                                  0                       1  \
# 0                                     Abierto sin pacto de
# 1                      Tipo de FIC
# 2                                              permanencia
# 3
# 4   Fecha de inicio de operaciones              19/08/1992
# 5
# 6
# 7         Valor fondo de inversión
# 8                                          $ 23,232,542.28
# 9             colectiva (Mill COP)
# 10
# 11
# 12           Número de unidades en
# 13                                      528,695,398.109067
# 14                     circulación
# 15
# 16
# 17                                  Calificación del Fondo
# 18
# 19                                  de Inversión Colectiva
# 20
# 21
# 22                                         Fecha de última
# 23                    Calificación
# 24                                            Calificación
# 25
# 26                    S1/AAAf(col)              30/10/2024
# 27
# ...

# %% [markdown]
# Este parece funcionar mejor de los titulos:
#
# poner los titulos y dejar cuantos de cuantos saca bien cada uno

# %%
# lattice: lines separated tables

lattice_tables = camelot.read_pdf('unoDeCadaUno/bancolombia_fiducuenta.pdf', pages='all', flavor='lattice')

for table in lattice_tables:
    print('Stream Table')
    print(table.df)
# Out:
# Stream Table
#                                                  0  \
# 0                                      Tipo de FIC
# 1                   Fecha de inicio de operaciones
# 2  Valor fondo de inversión \ncolectiva (Mill COP)
# 3              Número de unidades en \ncirculación
#
#                                     1
# 0  Abierto sin pacto de \npermanencia
# 1                          19/08/1992
# 2                     $ 23,232,542.28
# 3                  528,695,398.109067
# Stream Table
#                                         0                      1            2  \
# 0                      Valor de la Unidad                                   -
# 1                Número de Inversionistas                                   -
# 2          Inversión Inicial Mínima (COP)                         $ 50,000.00
# 3                      Saldo Mínimo (COP)                              $ 1.00
# 4   Tiempo de preaviso para retiro (Días)                                N.A.
# ...

# %% [markdown]
# Probemos primero para solo un bounding box.
